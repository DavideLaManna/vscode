# %%
import os
import json

def generate_level_document(json_data):
    """
    Takes a JSON data (as a dictionary) that contains a pdf_name and sections,
    and returns a string document summarizing the number of sections at each level.
    
    Parameters:
      json_data (dict): The JSON data containing keys "pdf_name" and "sections".
      
    Returns:
      str: A document with the pdf_name and counts of each level.
    """
    # Get the PDF name; default to "Unknown PDF" if not present
    pdf_name = json_data.get("pdf_name", "Unknown PDF")
    
    # Get the sections dictionary; default to an empty dict if not present
    sections = json_data.get("sections", {})
    
    # Create a dictionary to count sections per level
    level_counts = {}
    for key, section in sections.items():
        # Each section is expected to have a "level" attribute.
        level = section.get("level")
        if level is not None:
            level_counts[level] = level_counts.get(level, 0) + 1

    # Build the output document as a string
    document_lines = [f"PDF Name: {pdf_name}", "Level counts:"]
    for level in sorted(level_counts.keys()):
        document_lines.append(f"  Level {level}: {level_counts[level]} section(s)")
    
    return "\n".join(document_lines)


def process_all_json_files(start_folder):
    """
    Recursively processes all .json files in the given folder and its subfolders.
    For each JSON file found, it loads the JSON, generates a level document, and
    adds information about the subfolder (relative to the start folder).
    
    Parameters:
      start_folder (str): The root folder path to search for JSON files.
      
    Returns:
      str: A combined document containing the results for all JSON files.
    """
    documents = []
    for root, dirs, files in os.walk(start_folder):
        for file in files:
            if file.lower().endswith(".json"):
                file_path = os.path.join(root, file)
                try:
                    with open(file_path, "r", encoding="utf-8") as f:
                        json_data = json.load(f)
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
                    continue
                
                # Generate the document for this JSON file
                doc = generate_level_document(json_data)
                # Determine subfolder relative to the start_folder
                rel_path = os.path.relpath(root, start_folder)
                documents.append(f"File: {file} (Subfolder: {rel_path})\n{doc}")
    
    return "\n\n".join(documents)


if __name__ == "__main__":
    # Ask the user for the folder path; default to "dataset/extraction_results_renamed"
    folder_path = input("Enter the folder path (default: dataset/extraction_results_renamed): ").strip()
    if not folder_path:
        folder_path = "dataset/extraction_results_renamed"
    
    # Process all JSON files in the given folder and print the result
    combined_document = process_all_json_files(folder_path)
    print("\n=== Processing Results ===\n")
    print(combined_document)
# Out:
# === Processing Results ===
#
# File: ISO45001_ISO14001_POLICY_SSD0003_R01_EN.json (Subfolder: SSD)
# PDF Name: ISO45001_ISO14001_POLICY_SSD0003_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: MORT015_MORT017_MORT022_JDFT049_JDFT050_ZONE_2_DEU0019_R07_EN.json (Subfolder: DEU)
# PDF Name: MORT015_MORT017_MORT022_JDFT049_JDFT050_ZONE_2_DEU0019_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DI-03_DEU0122_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-IS-DI-03_DEU0122_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLI-01_DEU0140_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-RLI-01_DEU0140_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5263_D5264_DEU0032_R07_EN.json (Subfolder: DEU)
# PDF Name: D5263_D5264_DEU0032_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D9410_D9420_D9510_D9520_DEU0043_R05_EN.json (Subfolder: DEU)
# PDF Name: D9410_D9420_D9510_D9520_DEU0043_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D9401_DEU0044_R02_EN.json (Subfolder: DEU)
# PDF Name: D9401_DEU0044_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5000_BARRIERS_DEU0010_R14_EN.json (Subfolder: DEU)
# PDF Name: D5000_BARRIERS_DEU0010_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5231E_DEU0016_R13_EN.json (Subfolder: DEU)
# PDF Name: D5231E_DEU0016_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: TB_TBE_SERIES_DEU0045_R06_EN.json (Subfolder: DEU)
# PDF Name: TB_TBE_SERIES_DEU0045_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-PAS-01_DEU0138_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-PAS-01_DEU0138_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_SS-02_DEU0147_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-RLO_SS-02_DEU0147_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5000_RELAY_DEU0012_R17_EN.json (Subfolder: DEU)
# PDF Name: D5000_RELAY_DEU0012_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D1000_DEU0001_R20_EN.json (Subfolder: DEU)
# PDF Name: D1000_DEU0001_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D1000_ZONE_2_DEU0003_R21_EN.json (Subfolder: DEU)
# PDF Name: D1000_ZONE_2_DEU0003_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D1054_D1061_D1063_DEU0002_R15_EN.json (Subfolder: DEU)
# PDF Name: D1054_D1061_D1063_DEU0002_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DO-01_DEU0124_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-IS-DO-01_DEU0124_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D6000_D6200_SERIES_DEU0025_R12_EN.json (Subfolder: DEU)
# PDF Name: D6000_D6200_SERIES_DEU0025_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5244_DEU0035_R07_EN.json (Subfolder: DEU)
# PDF Name: D5244_DEU0035_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-AI-01_DEU0128_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-AI-01_DEU0128_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DI-04_DEU0135_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-DI-04_DEU0135_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PSD1000_ZONE_2_DEU0018_R05_EN.json (Subfolder: DEU)
# PDF Name: PSD1000_ZONE_2_DEU0018_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D6072_DEU0053_R03_EN.json (Subfolder: DEU)
# PDF Name: D6072_DEU0053_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: TBE-D5016-TRI-001_2_3_4_5_6_7_8_9_11_12_DEU0049_R04_EN.json (Subfolder: DEU)
# PDF Name: TBE-D5016-TRI-001_2_3_4_5_6_7_8_9_11_12_DEU0049_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_EM-03_DEU0143_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-RLO_EM-03_DEU0143_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PPC1090_PPC1092_PPC5092_DEU0014_R07_EN.json (Subfolder: DEU)
# PDF Name: PPC1090_PPC1092_PPC5092_DEU0014_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5000_RELAYS_DEU0027_R10_EN.json (Subfolder: DEU)
# PDF Name: D5000_RELAYS_DEU0027_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5040_D5240_DEU0023_R09_EN.json (Subfolder: DEU)
# PDF Name: D5040_D5240_DEU0023_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D6004_DEU0046_R05_EN.json (Subfolder: DEU)
# PDF Name: D6004_DEU0046_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DO-01_DEU0136_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-DO-01_DEU0136_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_SS-03_DEU0148_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-RLO_SS-03_DEU0148_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D2052M_D2053M_DEU0026_R05_EN.json (Subfolder: DEU)
# PDF Name: D2052M_D2053M_DEU0026_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D1048_D1049_D1061-077_DEU0017_R13_EN.json (Subfolder: DEU)
# PDF Name: D1048_D1049_D1061-077_DEU0017_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PSD5201_DEU0021_R10_EN.json (Subfolder: DEU)
# PDF Name: PSD5201_DEU0021_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_EM-01_DEU0141_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-RLO_EM-01_DEU0141_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_SS-01_DEU0146_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-RLO_SS-01_DEU0146_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DI-04_DEU0123_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-IS-DI-04_DEU0123_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-PAS-02_DEU0139_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-PAS-02_DEU0139_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D2000_DEU0007_R12_EN.json (Subfolder: DEU)
# PDF Name: D2000_DEU0007_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PSS1250_PSW1250_PSW1230_DEU0030_R11_EN.json (Subfolder: DEU)
# PDF Name: PSS1250_PSW1250_PSW1230_DEU0030_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5072_D5073_DEU0015_R12_EN.json (Subfolder: DEU)
# PDF Name: D5072_D5073_DEU0015_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-AI-01_DEU0169_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-IS-AI-01_DEU0169_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5274_DEU0112_R01_EN.json (Subfolder: DEU)
# PDF Name: D5274_DEU0112_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DI-01_DEU0132_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-DI-01_DEU0132_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5098_DEU0039_R05_EN.json (Subfolder: DEU)
# PDF Name: D5098_DEU0039_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PSD1000F_DEU0098_R01_EN.json (Subfolder: DEU)
# PDF Name: PSD1000F_DEU0098_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DO-02_DEU0125_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-IS-DO-02_DEU0125_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PSD1220_DEU0040_R04_EN.json (Subfolder: DEU)
# PDF Name: PSD1220_DEU0040_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5212_DEU0041_R06_EN.json (Subfolder: DEU)
# PDF Name: D5212_DEU0041_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-AI-02_DEU0170_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-IS-AI-02_DEU0170_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PSS1250_SAFE_DEU0071_R04_EN.json (Subfolder: DEU)
# PDF Name: PSS1250_SAFE_DEU0071_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5015_DEU0050_R03_EN.json (Subfolder: DEU)
# PDF Name: D5015_DEU0050_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5062_DEU0022_R10_EN.json (Subfolder: DEU)
# PDF Name: D5062_DEU0022_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5038_D5039_DEU0047_R04_EN.json (Subfolder: DEU)
# PDF Name: D5038_D5039_DEU0047_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5232_D5233_DEU0114_R01_EN.json (Subfolder: DEU)
# PDF Name: D5232_D5233_DEU0114_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DI-03_DEU0134_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-DI-03_DEU0134_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5254_DEU0034_R07_EN.json (Subfolder: DEU)
# PDF Name: D5254_DEU0034_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: TB_D6000_ZONE_2_DEU0042_R07_EN.json (Subfolder: DEU)
# PDF Name: TB_D6000_ZONE_2_DEU0042_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DO-02_DEU0137_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-DO-02_DEU0137_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DI-01_DEU0120_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-IS-DI-01_DEU0120_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: 5700_DEU0038_R06_EN.json (Subfolder: DEU)
# PDF Name: 5700_DEU0038_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_EM-02_DEU0142_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-RLO_EM-02_DEU0142_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-AI-02_DEU0129_R00_EN.json (Subfolder: DEU)
# PDF Name: X1-NIS-AI-02_DEU0129_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5016_DEU0100_R02_EN.json (Subfolder: DEU)
# PDF Name: D5016_DEU0100_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D5202_DEU0020_R11_EN.json (Subfolder: DEU)
# PDF Name: D5202_DEU0020_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: D6017_DEU0048_R04_EN.json (Subfolder: DEU)
# PDF Name: D6017_DEU0048_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DI-03_DUK0017_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-DI-03_DUK0017_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DI-04_DUK0006_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-IS-DI-04_DUK0006_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLI-01_DUK0023_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-RLI-01_DUK0023_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DI-01_DUK0003_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-IS-DI-01_DUK0003_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_EM-03_DUK0026_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-RLO_EM-03_DUK0026_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-PAS-02_DUK0022_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-PAS-02_DUK0022_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: PRIVACY_POLICY_WEBSITE_PVD0046_R02_EN.json (Subfolder: OTHER)
# PDF Name: PRIVACY_POLICY_WEBSITE_PVD0046_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 6 section(s)
#   Level 3: 12 section(s)
#
# File: COOKIE_POLICY_PVD0066_R02_EN.json (Subfolder: OTHER)
# PDF Name: COOKIE_POLICY_PVD0066_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 8 section(s)
#   Level 3: 2 section(s)
#
# File: X1-NIS-RLO_SS-03_DUK0031_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-RLO_SS-03_DUK0031_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DI-03_DUK0005_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-IS-DI-03_DUK0005_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-PAS-01_DUK0021_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-PAS-01_DUK0021_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DO-02_DUK0020_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-DO-02_DUK0020_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DI-04_DUK0018_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-DI-04_DUK0018_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_EM-02_DUK0025_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-RLO_EM-02_DUK0025_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-AI-02_DUK0053_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-IS-AI-02_DUK0053_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_SS-02_DUK0030_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-RLO_SS-02_DUK0030_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DO-01_DUK0019_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-DO-01_DUK0019_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_SS-01_DUK0029_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-RLO_SS-01_DUK0029_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-AI-02_DUK0012_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-AI-02_DUK0012_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DO-02_DUK0008_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-IS-DO-02_DUK0008_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-RLO_EM-01_DUK0024_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-RLO_EM-01_DUK0024_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-AI-01_DUK0011_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-AI-01_DUK0011_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-NIS-DI-01_DUK0015_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-NIS-DI-01_DUK0015_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-AI-01_DUK0052_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-IS-AI-01_DUK0052_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: X1-IS-DO-01_DUK0007_R00_EN.json (Subfolder: OTHER)
# PDF Name: X1-IS-DO-01_DUK0007_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: CROSS_MTL9600_GMI_PRODUCTS_XRF0020_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL9600_GMI_PRODUCTS_XRF0020_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#
# File: CROSS_MTL600_GMI_PRODUCTS_XRF0028_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL600_GMI_PRODUCTS_XRF0028_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 19 section(s)
#
# File: CROSS_MTL77000_GMI_PRODUCTS_XRF0006_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL77000_GMI_PRODUCTS_XRF0006_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: CROSS_MTL660_GMI_PRODUCTS_XRF0026_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL660_GMI_PRODUCTS_XRF0026_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 14 section(s)
#
# File: CROSS_MTL9400_GMI_PRODUCTS_XRF0019_R03_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL9400_GMI_PRODUCTS_XRF0019_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 16 section(s)
#
# File: CROSS_MTL_HMI_GMI_PRODUCTS_XRF0014_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL_HMI_GMI_PRODUCTS_XRF0014_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 8 section(s)
#
# File: CROSS_MTL7000_GMI_PRODUCTS_XRF0005_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL7000_GMI_PRODUCTS_XRF0005_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: CROSS_MTL4600_GMI_PRODUCTS_XRF0010_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL4600_GMI_PRODUCTS_XRF0010_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 36 section(s)
#
# File: CROSS_MTL9200_GMI_PRODUCTS_XRF0015_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL9200_GMI_PRODUCTS_XRF0015_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#
# File: CROSS_MTL2000_GMI_PRODUCTS_XRF0003_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL2000_GMI_PRODUCTS_XRF0003_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 18 section(s)
#
# File: CROSS_MTL9500_GMI_PRODUCTS_XRF0018_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL9500_GMI_PRODUCTS_XRF0018_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 10 section(s)
#
# File: CROSS_MTL9100_GMI_PRODUCTS_XRF0022_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL9100_GMI_PRODUCTS_XRF0022_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 11 section(s)
#
# File: CROSS_MTL700_GMI_PRODUCTS_XRF0004_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL700_GMI_PRODUCTS_XRF0004_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: CROSS_MTL4500_GMI_PRODUCTS_XRF0009_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL4500_GMI_PRODUCTS_XRF0009_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 58 section(s)
#
# File: CROSS_MTL1000_GMI_PRODUCTS_XRF0002_R01_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL1000_GMI_PRODUCTS_XRF0002_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 19 section(s)
#
# File: CROSS_MTL_SUM5_GMI_PRODUCTS_XRF0017_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL_SUM5_GMI_PRODUCTS_XRF0017_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#
# File: CROSS_MTL_GAS_ANALYZERS_GMI_PRODUCTS_XRF0011_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL_GAS_ANALYZERS_GMI_PRODUCTS_XRF0011_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 18 section(s)
#
# File: CROSS_MTL100_GMI_PRODUCTS_XRF0029_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL100_GMI_PRODUCTS_XRF0029_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 26 section(s)
#
# File: CROSS_MTL_FISCO_GMI_PRODUCTS_XRF0016_R02_EN.json (Subfolder: XRF)
# PDF Name: CROSS_MTL_FISCO_GMI_PRODUCTS_XRF0016_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 86 section(s)
#
# File: D5072-096_ISM0388_R08_EN.json (Subfolder: ISM)
# PDF Name: D5072-096_ISM0388_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 8 section(s)
#   Level 3: 12 section(s)
#
# File: SWC1091_ISM0085_R00_EN.json (Subfolder: ISM)
# PDF Name: SWC1091_ISM0085_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 10 section(s)
#   Level 3: 18 section(s)
#
# File: PSD1001C_ISM0065_R13_EN.json (Subfolder: ISM)
# PDF Name: PSD1001C_ISM0065_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 13 section(s)
#   Level 2: 6 section(s)
#
# File: UL_CDRW_D1032_ISM0130_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1032_ISM0130_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 3 section(s)
#   Level 2: 1 section(s)
#
# File: X1-NIS-DO-02_ISM0613_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-DO-02_ISM0613_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 18 section(s)
#
# File: UL_CDRW_D5014_ISM0273_R00_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5014_ISM0273_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 3 section(s)
#
# File: D6015_ISM0445_R01_EN.json (Subfolder: ISM)
# PDF Name: D6015_ISM0445_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 9 section(s)
#   Level 3: 11 section(s)
#
# File: D6212_ISM0455_R00_EN.json (Subfolder: ISM)
# PDF Name: D6212_ISM0455_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 12 section(s)
#   Level 3: 18 section(s)
#
# File: X1-NIS-RLO_EM-03_ISM0733_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_EM-03_ISM0733_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: D6263_ISM0473_R00_EN.json (Subfolder: ISM)
# PDF Name: D6263_ISM0473_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 8 section(s)
#   Level 3: 11 section(s)
#
# File: SIL_D6263S_ISM0475_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6263S_ISM0475_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: UL_CDRW_D1052_ISM0137_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1052_ISM0137_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 3 section(s)
#
# File: PSD5201_ISM0186_R07_EN.json (Subfolder: ISM)
# PDF Name: PSD5201_ISM0186_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 13 section(s)
#   Level 3: 12 section(s)
#
# File: D5037_ISM0270_R07_EN.json (Subfolder: ISM)
# PDF Name: D5037_ISM0270_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 18 section(s)
#   Level 3: 18 section(s)
#
# File: PSS1250_ISM0219_R17_EN.json (Subfolder: ISM)
# PDF Name: PSS1250_ISM0219_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 5 section(s)
#   Level 3: 88 section(s)
#
# File: X1-NIS-RLO_SS-02_ISM0626_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_SS-02_ISM0626_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 14 section(s)
#
# File: D5090_ISM0109_R17_EN.json (Subfolder: ISM)
# PDF Name: D5090_ISM0109_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 6 section(s)
#   Level 3: 14 section(s)
#
# File: D5290-079_ISM0153_R11_EN.json (Subfolder: ISM)
# PDF Name: D5290-079_ISM0153_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 14 section(s)
#   Level 3: 10 section(s)
#
# File: D6038_ISM0431_R02_EN.json (Subfolder: ISM)
# PDF Name: D6038_ISM0431_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 9 section(s)
#   Level 3: 10 section(s)
#
# File: X1-NIS-DI-01_ISM0598_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-DI-01_ISM0598_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 15 section(s)
#
# File: TBE-FIX-MT-xxx_ISM0552_R02_EN.json (Subfolder: ISM)
# PDF Name: TBE-FIX-MT-xxx_ISM0552_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#
# File: X1-NIS-AI-02_ISM0671_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-AI-02_ISM0671_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 5 section(s)
#
# File: SIL_D6001_ISM0384_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6001_ISM0384_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 5 section(s)
#
# File: D5290-091_ISM0294_R06_EN.json (Subfolder: ISM)
# PDF Name: D5290-091_ISM0294_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 12 section(s)
#   Level 3: 7 section(s)
#
# File: X1-IS-DI-03_ISM0636_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DI-03_ISM0636_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#
# File: SIL_D6231_ISM0423_R02_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6231_ISM0423_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: D1010_ISM0007_R19_EN.json (Subfolder: ISM)
# PDF Name: D1010_ISM0007_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 25 section(s)
#   Level 2: 25 section(s)
#
# File: D6017_ISM0453_R03_EN.json (Subfolder: ISM)
# PDF Name: D6017_ISM0453_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 8 section(s)
#   Level 3: 12 section(s)
#
# File: D1061_ISM0068_R14_EN.json (Subfolder: ISM)
# PDF Name: D1061_ISM0068_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 12 section(s)
#   Level 2: 5 section(s)
#
# File: X1-NIS-AI-02_ISM0589_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-AI-02_ISM0589_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 19 section(s)
#
# File: SIL_D1064_ISM0312_R01_EN.json (Subfolder: ISM)
# PDF Name: SIL_D1064_ISM0312_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: D1060_ISM0054_R18_EN.json (Subfolder: ISM)
# PDF Name: D1060_ISM0054_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 15 section(s)
#   Level 3: 6 section(s)
#
# File: X1-NIS-PAS-02_ISM0593_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-PAS-02_ISM0593_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 8 section(s)
#
# File: X1-NIS-RLO_EM-02_ISM0714_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_EM-02_ISM0714_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 15 section(s)
#
# File: UL_CDRW_D1060_ISM0140_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1060_ISM0140_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 5 section(s)
#   Level 3: 3 section(s)
#
# File: PSS1250-2-48_ISM0368_R01_EN.json (Subfolder: ISM)
# PDF Name: PSS1250-2-48_ISM0368_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 2 section(s)
#   Level 3: 23 section(s)
#
# File: D5094_ISM0299_R08_EN.json (Subfolder: ISM)
# PDF Name: D5094_ISM0299_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 6 section(s)
#
# File: SIL_D5014_ISM0382_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5014_ISM0382_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 23 section(s)
#
# File: SIL_D5097-107_ISM0467_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5097-107_ISM0467_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 4 section(s)
#
# File: UL_CDRW_D5020_ISM0274_R00_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5020_ISM0274_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: X1-NIS-RLO_SS-03_ISM0738_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_SS-03_ISM0738_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: UL_CDRW_D1031_ISM0129_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1031_ISM0129_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: D5290-078_ISM0152_R16_EN.json (Subfolder: ISM)
# PDF Name: D5290-078_ISM0152_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 17 section(s)
#   Level 3: 8 section(s)
#
# File: SIL_D6038_ISM0433_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6038_ISM0433_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 10 section(s)
#
# File: SIL_D5291-097_ISM0369_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5291-097_ISM0369_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 2 section(s)
#   Level 3: 1 section(s)
#
# File: X1-NIS-DI-03_ISM0679_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-DI-03_ISM0679_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: EX_SAF_D1000_ISM0155_R08_EN.json (Subfolder: ISM)
# PDF Name: EX_SAF_D1000_ISM0155_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 4 section(s)
#   Level 2: 44 section(s)
#   Level 3: 1 section(s)
#
# File: X1-NIS-PAS-01_ISM0667_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-PAS-01_ISM0667_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 10 section(s)
#
# File: D5293_ISM0122_R20_EN.json (Subfolder: ISM)
# PDF Name: D5293_ISM0122_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 17 section(s)
#   Level 3: 3 section(s)
#
# File: D1063_ISM0069_R13_EN.json (Subfolder: ISM)
# PDF Name: D1063_ISM0069_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 12 section(s)
#   Level 3: 14 section(s)
#
# File: D5015_ISM0397_R06_EN.json (Subfolder: ISM)
# PDF Name: D5015_ISM0397_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 13 section(s)
#
# File: EX_SAF_D6000_ISM0454_R02_EN.json (Subfolder: ISM)
# PDF Name: EX_SAF_D6000_ISM0454_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 4 section(s)
#   Level 2: 4 section(s)
#   Level 3: 1 section(s)
#
# File: D5093-TB_ISM0541_R05_EN.json (Subfolder: ISM)
# PDF Name: D5093-TB_ISM0541_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 11 section(s)
#   Level 3: 12 section(s)
#
# File: D1053_ISM0016_R15_EN.json (Subfolder: ISM)
# PDF Name: D1053_ISM0016_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 15 section(s)
#   Level 3: 4 section(s)
#
# File: X1-IS-DO-02_ISM0639_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DO-02_ISM0639_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 2 section(s)
#
# File: D1044_ISM0080_R12_EN.json (Subfolder: ISM)
# PDF Name: D1044_ISM0080_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 18 section(s)
#   Level 2: 18 section(s)
#   Level 3: 3 section(s)
#
# File: X1-NIS-DO-01_ISM0704_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-DO-01_ISM0704_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 15 section(s)
#
# File: D5016_ISM0581_R00_EN.json (Subfolder: ISM)
# PDF Name: D5016_ISM0581_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: SIL_D5098_ISM0314_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5098_ISM0314_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 4 section(s)
#
# File: UL_CDRW_D5048_D5049_ISM0279_R00_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5048_D5049_ISM0279_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 3 section(s)
#
# File: D1010-046_ISM0066_R13_EN.json (Subfolder: ISM)
# PDF Name: D1010-046_ISM0066_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 21 section(s)
#   Level 2: 15 section(s)
#   Level 3: 14 section(s)
#
# File: SIL_D5096-106_ISM0466_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5096-106_ISM0466_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 4 section(s)
#
# File: SIL_D5263_ISM0449_R01_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5263_ISM0449_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 4 section(s)
#
# File: X1-IS-DI-01_ISM0685_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DI-01_ISM0685_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 17 section(s)
#   Level 3: 1 section(s)
#
# File: SIL_D6016_ISM0556_R01_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6016_ISM0556_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 15 section(s)
#
# File: FM_CDRW_D5293_D5294_ISM0165_R00_EN.json (Subfolder: ISM)
# PDF Name: FM_CDRW_D5293_D5294_ISM0165_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 3 section(s)
#
# File: UL_CDRW_D1041_ISM0134_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1041_ISM0134_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: X1-NIS-RLO_EM-03_ISM0624_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_EM-03_ISM0624_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 13 section(s)
#   Level 3: 1 section(s)
#
# File: SIL_D5094-104_ISM0464_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5094-104_ISM0464_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 4 section(s)
#
# File: D1093_ISM0093_R16_EN.json (Subfolder: ISM)
# PDF Name: D1093_ISM0093_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 13 section(s)
#   Level 3: 5 section(s)
#
# File: PSW1250_ISM0220_R13_EN.json (Subfolder: ISM)
# PDF Name: PSW1250_ISM0220_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 35 section(s)
#   Level 3: 35 section(s)
#
# File: SIL_D6072-096_ISM0444_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6072-096_ISM0444_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: X1-NIS-DI-03_ISM0600_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-DI-03_ISM0600_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 14 section(s)
#
# File: SIL_D5095_ISM0307_R01_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5095_ISM0307_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 5 section(s)
#
# File: X1-IS-AI-01_ISM0681_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-AI-01_ISM0681_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 17 section(s)
#   Level 3: 5 section(s)
#
# File: X1-IS-AI-02_ISM0669_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-AI-02_ISM0669_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 5 section(s)
#
# File: D6017-TB_ISM0547_R02_EN.json (Subfolder: ISM)
# PDF Name: D6017-TB_ISM0547_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 8 section(s)
#   Level 3: 12 section(s)
#
# File: D9420_ISM0376_R03_EN.json (Subfolder: ISM)
# PDF Name: D9420_ISM0376_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#   Level 3: 5 section(s)
#
# File: D5040_ISM0187_R12_EN.json (Subfolder: ISM)
# PDF Name: D5040_ISM0187_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 13 section(s)
#   Level 3: 16 section(s)
#
# File: TIIS_CDRW_D5072_ISM0192_R00_EN.json (Subfolder: ISM)
# PDF Name: TIIS_CDRW_D5072_ISM0192_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 4 section(s)
#
# File: X1-NIS-DI-03_ISM0691_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-DI-03_ISM0691_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 15 section(s)
#
# File: SIL_D6072-087_ISM0422_R01_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6072-087_ISM0422_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: TBE-TRI_TRICON_TRICONCX_ISM0452_R10_EN.json (Subfolder: ISM)
# PDF Name: TBE-TRI_TRICON_TRICONCX_ISM0452_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 16 section(s)
#   Level 3: 57 section(s)
#
# File: SIL_D5273_ISM0426_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5273_ISM0426_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: D5036_ISM0269_R07_EN.json (Subfolder: ISM)
# PDF Name: D5036_ISM0269_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 16 section(s)
#   Level 3: 17 section(s)
#
# File: CCC_Ex_Safety_ISM0584_R00_EN.json (Subfolder: ISM)
# PDF Name: CCC_Ex_Safety_ISM0584_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 3 section(s)
#   Level 2: 5 section(s)
#   Level 3: 1 section(s)
#
# File: FM_CDRW_D5030_D5031_D5032_ISM0161_R00_EN.json (Subfolder: ISM)
# PDF Name: FM_CDRW_D5030_D5031_D5032_ISM0161_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#   Level 3: 2 section(s)
#
# File: SIL_D5095-105_ISM0465_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5095-105_ISM0465_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 4 section(s)
#
# File: D5011_ISM0124_R12_EN.json (Subfolder: ISM)
# PDF Name: D5011_ISM0124_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 11 section(s)
#   Level 3: 5 section(s)
#
# File: D6231_ISM0217_R03_EN.json (Subfolder: ISM)
# PDF Name: D6231_ISM0217_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 16 section(s)
#   Level 3: 13 section(s)
#
# File: D1072_ISM0018_R22_EN.json (Subfolder: ISM)
# PDF Name: D1072_ISM0018_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 15 section(s)
#   Level 3: 12 section(s)
#
# File: FM_CDRW_D5011_ISM0158_R00_EN.json (Subfolder: ISM)
# PDF Name: FM_CDRW_D5011_ISM0158_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 2 section(s)
#
# File: SIL_D6004_ISM0451_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6004_ISM0451_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: D6072_109_ISM0548_R02_EN.json (Subfolder: ISM)
# PDF Name: D6072_109_ISM0548_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 14 section(s)
#   Level 3: 4 section(s)
#
# File: SIL_D5011_ISM0381_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5011_ISM0381_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 4 section(s)
#   Level 3: 9 section(s)
#
# File: D1034_ISM0053_R16_EN.json (Subfolder: ISM)
# PDF Name: D1034_ISM0053_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 15 section(s)
#   Level 3: 6 section(s)
#
# File: SIL_D5254_ISM0315_R02_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5254_ISM0315_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 13 section(s)
#   Level 3: 21 section(s)
#
# File: D1020_ISM0012_R16_EN.json (Subfolder: ISM)
# PDF Name: D1020_ISM0012_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 16 section(s)
#   Level 2: 9 section(s)
#
# File: D1048_ISM0096_R09_EN.json (Subfolder: ISM)
# PDF Name: D1048_ISM0096_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 12 section(s)
#   Level 3: 9 section(s)
#
# File: SIL_D6014_ISM0400_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6014_ISM0400_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 23 section(s)
#
# File: D9520_ISM0378_R03_EN.json (Subfolder: ISM)
# PDF Name: D9520_ISM0378_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#   Level 3: 5 section(s)
#
# File: SIL_D6031_ISM0404_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6031_ISM0404_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 18 section(s)
#   Level 3: 25 section(s)
#
# File: SIL_TBE-5008-TRI-001_TBE-D5016-001_to_12_ISM0472_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_TBE-5008-TRI-001_TBE-D5016-001_to_12_ISM0472_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 85 section(s)
#   Level 3: 77 section(s)
#
# File: D5274_ISM0664_R00_EN.json (Subfolder: ISM)
# PDF Name: D5274_ISM0664_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 1 section(s)
#
# File: SIL_D5038_ISM0429_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5038_ISM0429_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 10 section(s)
#
# File: PSD1210_PSD1206_ISM0071_R13_EN.json (Subfolder: ISM)
# PDF Name: PSD1210_PSD1206_ISM0071_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 10 section(s)
#   Level 2: 33 section(s)
#   Level 3: 29 section(s)
#
# File: SIL_D5015_ISM0398_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5015_ISM0398_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 4 section(s)
#   Level 3: 8 section(s)
#
# File: SIL_D6072-109_ISM0567_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6072-109_ISM0567_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 2 section(s)
#   Level 3: 2 section(s)
#
# File: D5231_ISM0286_R00_EN.json (Subfolder: ISM)
# PDF Name: D5231_ISM0286_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 1 section(s)
#
# File: X1-IS-AI-02_ISM0587_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-AI-02_ISM0587_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 22 section(s)
#
# File: D6004_ISM0447_R05_EN.json (Subfolder: ISM)
# PDF Name: D6004_ISM0447_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 8 section(s)
#   Level 3: 9 section(s)
#
# File: SIL_D6254_ISM0424_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6254_ISM0424_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 13 section(s)
#   Level 3: 20 section(s)
#
# File: D5295_ISM0222_R14_EN.json (Subfolder: ISM)
# PDF Name: D5295_ISM0222_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 12 section(s)
#   Level 3: 8 section(s)
#
# File: SIL_D5295_ISM0443_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5295_ISM0443_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 8 section(s)
#   Level 3: 5 section(s)
#
# File: UL_CDRW_D1053_ISM0138_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1053_ISM0138_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 3 section(s)
#
# File: D6032_ISM0405_R01_EN.json (Subfolder: ISM)
# PDF Name: D6032_ISM0405_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 13 section(s)
#   Level 3: 13 section(s)
#
# File: D5274_ISM0661_R01_EN.json (Subfolder: ISM)
# PDF Name: D5274_ISM0661_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 11 section(s)
#   Level 3: 10 section(s)
#
# File: X1-IS-AI-02_ISM0682_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-AI-02_ISM0682_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 17 section(s)
#   Level 3: 5 section(s)
#
# File: D1130_ISM0048_R15_EN.json (Subfolder: ISM)
# PDF Name: D1130_ISM0048_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 7 section(s)
#   Level 2: 13 section(s)
#   Level 3: 9 section(s)
#
# File: X1-NIS-AI-01_ISM0683_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-AI-01_ISM0683_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 15 section(s)
#
# File: SIL_D6062_ISM0418_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6062_ISM0418_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 6 section(s)
#
# File: D6037_ISM0409_R01_EN.json (Subfolder: ISM)
# PDF Name: D6037_ISM0409_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 12 section(s)
#   Level 3: 6 section(s)
#
# File: SIL_D6020_ISM0402_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6020_ISM0402_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 3 section(s)
#   Level 3: 5 section(s)
#
# File: SIL_D6036_ISM0408_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6036_ISM0408_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 5 section(s)
#
# File: UL_CDRW_D5030_D5031_D5032_ISM0275_R00_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5030_D5031_D5032_ISM0275_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: D1052_ISM0015_R15_EN.json (Subfolder: ISM)
# PDF Name: D1052_ISM0015_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 13 section(s)
#   Level 2: 10 section(s)
#
# File: X1-NIS-RLO_SS-02_ISM0709_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_SS-02_ISM0709_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 16 section(s)
#
# File: D5240_ISM0209_R12_EN.json (Subfolder: ISM)
# PDF Name: D5240_ISM0209_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 14 section(s)
#   Level 3: 17 section(s)
#
# File: X1-IS-DI-03_ISM0596_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DI-03_ISM0596_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 17 section(s)
#
# File: X1-NIS-RLI-01_ISM0730_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLI-01_ISM0730_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 5 section(s)
#   Level 3: 12 section(s)
#
# File: SIL_D6034_ISM0401_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6034_ISM0401_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 3 section(s)
#   Level 3: 4 section(s)
#
# File: 5700_ISM0366_R07_EN.json (Subfolder: ISM)
# PDF Name: 5700_ISM0366_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 48 section(s)
#   Level 3: 65 section(s)
#
# File: D5095_ISM0300_R08_EN.json (Subfolder: ISM)
# PDF Name: D5095_ISM0300_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 9 section(s)
#   Level 3: 5 section(s)
#
# File: X1-NIS-PAS-02_ISM0695_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-PAS-02_ISM0695_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 14 section(s)
#
# File: PSD1001_ISM0023_R13_EN.json (Subfolder: ISM)
# PDF Name: PSD1001_ISM0023_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 11 section(s)
#   Level 2: 4 section(s)
#
# File: SIL_D6212_ISM0469_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6212_ISM0469_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: SIL_D5039_ISM0430_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5039_ISM0430_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 10 section(s)
#
# File: X1-IS-DO-02_ISM0611_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DO-02_ISM0611_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 23 section(s)
#
# File: SIL_D5016_ISM0555_R01_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5016_ISM0555_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 15 section(s)
#
# File: D5232_ISM0659_R00_EN.json (Subfolder: ISM)
# PDF Name: D5232_ISM0659_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 13 section(s)
#
# File: D6016_ISM0554_R01_EN.json (Subfolder: ISM)
# PDF Name: D6016_ISM0554_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 9 section(s)
#   Level 3: 9 section(s)
#
# File: SIL_PSD1220_PSD1220-098_ISM0371_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_PSD1220_PSD1220-098_ISM0371_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 40 section(s)
#   Level 3: 43 section(s)
#
# File: X1-IS-DO-02_ISM0703_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DO-02_ISM0703_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 17 section(s)
#   Level 3: 1 section(s)
#
# File: FM_CDRW_D5034_ISM0162_R00_EN.json (Subfolder: ISM)
# PDF Name: FM_CDRW_D5034_ISM0162_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 2 section(s)
#
# File: D5099-108_ISM0538_R01_EN.json (Subfolder: ISM)
# PDF Name: D5099-108_ISM0538_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 2 section(s)
#
# File: SIL_D5031_ISM0364_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5031_ISM0364_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 17 section(s)
#   Level 3: 23 section(s)
#
# File: UL_CDRW_D5015_ISM0440_R00_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5015_ISM0440_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 2 section(s)
#   Level 3: 2 section(s)
#
# File: D1030_ISM0008_R17_EN.json (Subfolder: ISM)
# PDF Name: D1030_ISM0008_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 17 section(s)
#   Level 2: 11 section(s)
#   Level 3: 1 section(s)
#
# File: D6031_ISM0214_R03_EN.json (Subfolder: ISM)
# PDF Name: D6031_ISM0214_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 13 section(s)
#   Level 3: 12 section(s)
#
# File: D5291_ISM0112_R18_EN.json (Subfolder: ISM)
# PDF Name: D5291_ISM0112_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 9 section(s)
#   Level 3: 14 section(s)
#
# File: X1-NIS-RLO_SS-01_ISM0625_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_SS-01_ISM0625_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 14 section(s)
#
# File: X1-NIS-RLO_EM-01_ISM0622_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_EM-01_ISM0622_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 13 section(s)
#
# File: D1062_ISM0094_R09_EN.json (Subfolder: ISM)
# PDF Name: D1062_ISM0094_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 10 section(s)
#   Level 2: 3 section(s)
#
# File: X1-NIS-RLO_SS-03_ISM0710_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_SS-03_ISM0710_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 16 section(s)
#
# File: D2000_ISM0078_R03_EN.json (Subfolder: ISM)
# PDF Name: D2000_ISM0078_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 17 section(s)
#   Level 2: 54 section(s)
#   Level 3: 53 section(s)
#
# File: D1033_ISM0043_R17_EN.json (Subfolder: ISM)
# PDF Name: D1033_ISM0043_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 7 section(s)
#   Level 3: 15 section(s)
#
# File: D6014_ISM0210_R03_EN.json (Subfolder: ISM)
# PDF Name: D6014_ISM0210_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
# ...
# PDF Name: D1014_ISM0052_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 15 section(s)
#   Level 2: 8 section(s)
#   Level 3: 5 section(s)
#
# File: EX_SAF_D5000_ISM0156_R21_EN.json (Subfolder: ISM)
# PDF Name: EX_SAF_D5000_ISM0156_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 4 section(s)
#   Level 2: 39 section(s)
#   Level 3: 1 section(s)
#
# File: UL_CDRW_D5072_ISM0282_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5072_ISM0282_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 8 section(s)
#   Level 3: 6 section(s)
#
# File: nan_ISM0748_R00_EN.json (Subfolder: ISM)
# PDF Name: nan_ISM0748_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 19 section(s)
#
# File: D1049_ISM0097_R11_EN.json (Subfolder: ISM)
# PDF Name: D1049_ISM0097_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 13 section(s)
#   Level 3: 3 section(s)
#
# File: D1081_ISM0056_R12_EN.json (Subfolder: ISM)
# PDF Name: D1081_ISM0056_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 12 section(s)
#   Level 2: 3 section(s)
#
# File: X1-IS-AI-01_ISM0630_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-AI-01_ISM0630_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#
# File: D6072_ISM0216_R12_EN.json (Subfolder: ISM)
# PDF Name: D6072_ISM0216_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 16 section(s)
#   Level 3: 6 section(s)
#
# File: SIL_D5231E_ISM0527_R01_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5231E_ISM0527_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: UL_CDRW_D1054_ISM0139_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1054_ISM0139_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 6 section(s)
#
# File: SIL_D6264S_ISM0476_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6264S_ISM0476_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: FM_CDRW_D5014_ISM0159_R00_EN.json (Subfolder: ISM)
# PDF Name: FM_CDRW_D5014_ISM0159_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 3 section(s)
#
# File: UL_CDRW_D1043_ISM0136_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1043_ISM0136_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 6 section(s)
#   Level 3: 6 section(s)
#
# File: UL_CDRW_D1072_ISM0141_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1072_ISM0141_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: D6020_ISM0212_R04_EN.json (Subfolder: ISM)
# PDF Name: D6020_ISM0212_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 2 section(s)
#
# File: PSD1000_ISM0089_R04_EN.json (Subfolder: ISM)
# PDF Name: PSD1000_ISM0089_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 7 section(s)
#   Level 2: 6 section(s)
#   Level 3: 1 section(s)
#
# File: D6003_ISM0395_R05_EN.json (Subfolder: ISM)
# PDF Name: D6003_ISM0395_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 5 section(s)
#
# File: SIL_D5294_ISM0442_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5294_ISM0442_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 8 section(s)
#   Level 3: 5 section(s)
#
# File: D6062_ISM0417_R02_EN.json (Subfolder: ISM)
# PDF Name: D6062_ISM0417_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 11 section(s)
#   Level 3: 8 section(s)
#
# File: SWC1090_ISM0084_R03_EN.json (Subfolder: ISM)
# PDF Name: SWC1090_ISM0084_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 7 section(s)
#   Level 2: 12 section(s)
#   Level 3: 9 section(s)
#
# File: D5212_ISM0361_R06_EN.json (Subfolder: ISM)
# PDF Name: D5212_ISM0361_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 14 section(s)
#   Level 3: 20 section(s)
#
# File: D1012_ISM0070_R10_EN.json (Subfolder: ISM)
# PDF Name: D1012_ISM0070_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 10 section(s)
#   Level 2: 7 section(s)
#
# File: X1-IS-DI-04_ISM0676_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DI-04_ISM0676_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: D1054_ISM0067_R20_EN.json (Subfolder: ISM)
# PDF Name: D1054_ISM0067_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 20 section(s)
#   Level 3: 26 section(s)
#
# File: D1010_ISM0098_R10_EN.json (Subfolder: ISM)
# PDF Name: D1010_ISM0098_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 13 section(s)
#   Level 2: 6 section(s)
#   Level 3: 1 section(s)
#
# File: D1045_ISM0081_R09_EN.json (Subfolder: ISM)
# PDF Name: D1045_ISM0081_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 12 section(s)
#   Level 3: 6 section(s)
#
# File: D5072_ISM0157_R18_EN.json (Subfolder: ISM)
# PDF Name: D5072_ISM0157_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 16 section(s)
#   Level 3: 5 section(s)
#
# File: CCC_EX_SAFETY_INSTRUCTION_D1000_ISM0602_R00_EN.json (Subfolder: ISM)
# PDF Name: CCC_EX_SAFETY_INSTRUCTION_D1000_ISM0602_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 4 section(s)
#   Level 2: 6 section(s)
#
# File: D9510_ISM0377_R03_EN.json (Subfolder: ISM)
# PDF Name: D9510_ISM0377_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 2 section(s)
#   Level 3: 5 section(s)
#
# File: SIL_D6017_ISM0471_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6017_ISM0471_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 3 section(s)
#   Level 3: 5 section(s)
#
# File: SIL_D5072-096_ISM0391_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5072-096_ISM0391_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: SIL_D5212_ISM0468_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5212_ISM0468_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 2 section(s)
#
# File: D1073_ISM0019_R22_EN.json (Subfolder: ISM)
# PDF Name: D1073_ISM0019_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 19 section(s)
#   Level 3: 14 section(s)
#
# File: UL_CDRW_D1014_ISM0126_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1014_ISM0126_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 3 section(s)
#   Level 2: 1 section(s)
#
# File: SIL_D6011_ISM0399_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D6011_ISM0399_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 4 section(s)
#   Level 3: 9 section(s)
#
# File: D5072-087_ISM0178_R14_EN.json (Subfolder: ISM)
# PDF Name: D5072-087_ISM0178_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 11 section(s)
#   Level 3: 15 section(s)
#
# File: D6011_ISM0211_R03_EN.json (Subfolder: ISM)
# PDF Name: D6011_ISM0211_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 1 section(s)
#
# File: D6254_ISM0310_R03_EN.json (Subfolder: ISM)
# PDF Name: D6254_ISM0310_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 13 section(s)
#   Level 3: 5 section(s)
#
# File: D5290-084_ISM0170_R11_EN.json (Subfolder: ISM)
# PDF Name: D5290-084_ISM0170_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 14 section(s)
#   Level 3: 8 section(s)
#
# File: D5096-100_ISM0439_R06_EN.json (Subfolder: ISM)
# PDF Name: D5096-100_ISM0439_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 10 section(s)
#   Level 3: 7 section(s)
#
# File: X1-IS-AI-01_ISM0586_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-AI-01_ISM0586_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 22 section(s)
#
# File: TBE-FIX-PL-001_ISM0551_R02_EN.json (Subfolder: ISM)
# PDF Name: TBE-FIX-PL-001_ISM0551_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: UL_CDRW_D5040_ISM0278_R00_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5040_ISM0278_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 7 section(s)
#   Level 3: 5 section(s)
#
# File: D6034_ISM0215_R03_EN.json (Subfolder: ISM)
# PDF Name: D6034_ISM0215_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 9 section(s)
#   Level 3: 2 section(s)
#
# File: FM_CDRW_D5048_D5049_ISM0163_R00_EN.json (Subfolder: ISM)
# PDF Name: FM_CDRW_D5048_D5049_ISM0163_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 2 section(s)
#
# File: X1-NIS-RLO_EM-01_ISM0713_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_EM-01_ISM0713_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 15 section(s)
#
# File: FM_CDRW_D5273_ISM0169_R00_EN.json (Subfolder: ISM)
# PDF Name: FM_CDRW_D5273_ISM0169_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: D1180_ISM0057_R12_EN.json (Subfolder: ISM)
# PDF Name: D1180_ISM0057_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 11 section(s)
#   Level 3: 9 section(s)
#
# File: PSD1220_PSD1220-098_ISM0370_R09_EN.json (Subfolder: ISM)
# PDF Name: PSD1220_PSD1220-098_ISM0370_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 2 section(s)
#   Level 3: 16 section(s)
#
# File: SIL_D5290-092_ISM0373_R00_EN.json (Subfolder: ISM)
# PDF Name: SIL_D5290-092_ISM0373_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 3 section(s)
#   Level 3: 2 section(s)
#
# File: UL_CDRW_D1130_ISM0143_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1130_ISM0143_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 3 section(s)
#   Level 2: 1 section(s)
#
# File: UL_CDRW_D1034_ISM0132_R01_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D1034_ISM0132_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 2 section(s)
#
# File: X1-NIS-RLO_SS-01_ISM0708_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLO_SS-01_ISM0708_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 16 section(s)
#
# File: D5233_ISM0666_R00_EN.json (Subfolder: ISM)
# PDF Name: D5233_ISM0666_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 1 section(s)
#
# File: X1-IS-DI-01_ISM0673_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DI-01_ISM0673_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#   Level 3: 3 section(s)
#
# File: X1-NIS-RLI-01_ISM0590_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-NIS-RLI-01_ISM0590_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 5 section(s)
#   Level 2: 13 section(s)
#
# File: SWC5090_ISM0154_R15_EN.json (Subfolder: ISM)
# PDF Name: SWC5090_ISM0154_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 10 section(s)
#   Level 2: 20 section(s)
#   Level 3: 66 section(s)
#
# File: UL_CDRW_D5036_D5037_ISM0277_R00_EN.json (Subfolder: ISM)
# PDF Name: UL_CDRW_D5036_D5037_ISM0277_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 3 section(s)
#   Level 3: 1 section(s)
#
# File: D5291-097_ISM0367_R04_EN.json (Subfolder: ISM)
# PDF Name: D5291-097_ISM0367_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 8 section(s)
#   Level 3: 3 section(s)
#
# File: X1-IS-DI-03_ISM0687_R00_EN.json (Subfolder: ISM)
# PDF Name: X1-IS-DI-03_ISM0687_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 17 section(s)
#   Level 3: 1 section(s)
#
# File: D5254_ISM0293_R12_EN.json (Subfolder: ISM)
# PDF Name: D5254_ISM0293_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 12 section(s)
#   Level 3: 6 section(s)
#
# File: D1072_D1073_APN0006_R00_EN.json (Subfolder: APN)
# PDF Name: D1072_D1073_APN0006_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#
# File: D1053S_APN0018_R00_EN.json (Subfolder: APN)
# PDF Name: D1053S_APN0018_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 3 section(s)
#
# File: D1000_APN0010_R00_EN.json (Subfolder: APN)
# PDF Name: D1000_APN0010_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 3 section(s)
#   Level 2: 7 section(s)
#   Level 3: 1 section(s)
#
# File: 3626X_TBE-D5016-TRI-007_009_APN0042_R00_EN.json (Subfolder: APN)
# PDF Name: 3626X_TBE-D5016-TRI-007_009_APN0042_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 9 section(s)
#   Level 3: 9 section(s)
#
# File: 3809X_TB-D5016-TRI-010_APN0044_R00_EN.json (Subfolder: APN)
# PDF Name: 3809X_TB-D5016-TRI-010_APN0044_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 8 section(s)
#   Level 3: 8 section(s)
#
# File: 3902X_TB-D5016-TRI-010_APN0045_R00_EN.json (Subfolder: APN)
# PDF Name: 3902X_TB-D5016-TRI-010_APN0045_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 8 section(s)
#   Level 3: 8 section(s)
#
# File: D1052_D1053_D1054_D1060_D1072_D1073_APN0005_R01_EN.json (Subfolder: APN)
# PDF Name: D1052_D1053_D1054_D1060_D1072_D1073_APN0005_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 1 section(s)
#
# File: D1020D_APN0002_R00_EN.json (Subfolder: APN)
# PDF Name: D1020D_APN0002_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 2 section(s)
#
# File: D1020-027_APN0004_R00_EN.json (Subfolder: APN)
# PDF Name: D1020-027_APN0004_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#
# File: 3722X_3723X_TBE-D5016-TRI-011_APN0043_R00_EN.json (Subfolder: APN)
# PDF Name: 3722X_3723X_TBE-D5016-TRI-011_APN0043_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 4 section(s)
#   Level 3: 6 section(s)
#
# File: D1072-073_APN0012_R00_EN.json (Subfolder: APN)
# PDF Name: D1072-073_APN0012_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 1 section(s)
#
# File: D5091S_D5294S_D5295S_APN0037_R00_EN.json (Subfolder: APN)
# PDF Name: D5091S_D5294S_D5295S_APN0037_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 3 section(s)
#   Level 2: 3 section(s)
#   Level 3: 4 section(s)
#
# File: D1072-024_APN0020_R00_EN.json (Subfolder: APN)
# PDF Name: D1072-024_APN0020_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#
# File: TRICON_TRICON-CX_TRIDENT_TRI-GP_APN0046_R00_EN.json (Subfolder: APN)
# PDF Name: TRICON_TRICON-CX_TRIDENT_TRI-GP_APN0046_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 7 section(s)
#   Level 3: 4 section(s)
#
# File: D5293S_D5294S_APN0036_R01_EN.json (Subfolder: APN)
# PDF Name: D5293S_D5294S_APN0036_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 2 section(s)
#   Level 2: 7 section(s)
#   Level 3: 23 section(s)
#
# File: D1052X_APN0022_R00_EN.json (Subfolder: APN)
# PDF Name: D1052X_APN0022_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#
# File: PSD1000_APN0007_R01_EN.json (Subfolder: APN)
# PDF Name: PSD1000_APN0007_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#
# File: D1072D-028_APN0008_R00_EN.json (Subfolder: APN)
# PDF Name: D1072D-028_APN0008_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#   Level 2: 2 section(s)
#
# File: D5231_D6231_SIL_DECLARATION_DOC0062_R00_EN.json (Subfolder: DOC)
# PDF Name: D5231_D6231_SIL_DECLARATION_DOC0062_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: IECEX_D5090_D5091_D5290_D5291_D5293_D5294_DOC0006_R01_EN.json (Subfolder: DOC)
# PDF Name: IECEX_D5090_D5091_D5290_D5291_D5293_D5294_DOC0006_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: IECEX_D5030_D5032_DOC0005_R01_EN.json (Subfolder: DOC)
# PDF Name: IECEX_D5030_D5032_DOC0005_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
#
# File: IECEX_D5011_D5014_D5020_D5031_D5034_D5048_D5049_DOC0004_R01_EN.json (Subfolder: DOC)
# PDF Name: IECEX_D5011_D5014_D5020_D5031_D5034_D5048_D5049_DOC0004_EN
# Level counts:
#   Level 0: 1 section(s)
#   Level 1: 1 section(s)
